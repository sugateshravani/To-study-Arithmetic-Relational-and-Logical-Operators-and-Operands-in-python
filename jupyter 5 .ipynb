# %% [markdown]
# <a href="https://colab.research.google.com/github/sugateshravani/To-study-Arithmetic-Relational-and-Logical-Operators-and-Operands-in-python/blob/main/jupyter%205%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 WAP to Calculate Length of String
string = input("Enter a string: ")
length = len(string)
print("Length of string is:", length)
# Out:
# Enter a string: Shravani
# Length of string is: 8

# %%
#2 WAP to Make String from First 2 and Last 2 Characters
string = input("Enter a string: ")

if len(string) < 2:
    print("Empty string")
else:
    result = string[:2] + string[-2:]
    print("New string:", result)
# Out:
# Enter a string: Python
# New string: Pyn

# %%
#3 WAP to Concatenate Two Strings
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

result = str1 + str2
print("Concatenated string:", result)
# Out:
# Enter first string: Shravani
# Enter second string: Sugate
# Concatenated string: ShravaniSugate
